# %%
import requests
import pandas as pd
import pymongo

# %%
# can be a single line of code!

card_requests = requests.get('https://api.scryfall.com/bulk-data').json()['data'][0]['download_uri']
#started with just request + json()
# drilled down to the download_uri


cards = requests.get(card_requests).json()
# created separate request with the download_uri that came from the first response

df = pd.DataFrame.from_dict(cards)
# turned the response(dict) into a dataframe

# %%
df
# Out:
#       object                                    id  \
# 0       card  86bf43b1-8d4e-4759-bb2d-0b2e03ba7012
# 1       card  7050735c-b232-47a6-a342-01795bfd0d46
# 2       card  e718b21b-46d1-4844-985c-52745657b1ac
# 3       card  036ef8c9-72ac-46ce-af07-83b79d736538
# 4       card  b125d1e7-5d9b-4997-88b0-71bdfc19c6f2
# ...      ...                                   ...
# 29952   card  d6695fa8-881c-407c-91d9-3ac770372d35
# 29953   card  4d5edf4f-5695-42fc-9e57-c4faef60fbc3
# 29954   card  22a6a5f1-1405-4efb-af3e-e1f58d664e99
# 29955   card  09f06f55-7918-46c4-80ff-0bf39e091a4a
# 29956   card  1ecc983e-bbe3-4bc1-97e9-e40ead987ef0
#
#                                   oracle_id    multiverse_ids   mtgo_id  \
# 0      0004ebd0-dfd6-4276-b4a6-de0003e94237           [15862]   15870.0
# 1      0006faf6-7a61-426c-9034-579f2cfcfa83          [370780]   49283.0
# 2      0007c283-5b7a-4c00-9ca1-b455c8dff8c3          [470580]   77122.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29957 entries, 0 to 29956
# Data columns (total 80 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   object               29957 non-null  object
#  1   id                   29957 non-null  object
#  2   oracle_id            29957 non-null  object
#  3   multiverse_ids       29957 non-null  object
#  4   mtgo_id              21534 non-null  float64
#  5   mtgo_foil_id         11930 non-null  float64
#  6   tcgplayer_id         26129 non-null  float64
#  7   cardmarket_id        25584 non-null  float64
#  8   name                 29957 non-null  object
#  9   lang                 29957 non-null  object
#  10  released_at          29957 non-null  object
#  11  uri                  29957 non-null  object
#  12  scryfall_uri         29957 non-null  object
#  13  layout               29957 non-null  object
#  14  highres_image        29957 non-null  bool
# ...

# %% [markdown]
# # adding to mongoDB

# %%
# getting the url from mongo 
con_str = 'mongodb+srv://bonfire_sid:789eleVAtor@cluster0.sdwodbu.mongodb.net/?retryWrites=true&w=majority'

client  = pymongo.MongoClient(con_str)

# %%
# i dont quite understand this part, look up the documentation later
# now we can create db and connections

db = client.db

# create a collection from the database

cards = db.cards

df.set_index('id', inplace=True)

# %%
# mongodb has a max upload size: limited to some number of bytes
'''
cards.insert_many([df.to_dict()])
'''
# results in an error
# the connected server supports BSON document sizes up to 16777216 bytes

# %%
for i in df.index[:4]:
    cards.insert_one(df.loc[i].to_dict())

# %%
for i in df.index[:5]:
    print(df.loc[i])
    # cards.insert_one(df.loc[i].to_dict())
# Out:
# object                                               card
# oracle_id            0004ebd0-dfd6-4276-b4a6-de0003e94237
# multiverse_ids                                    [15862]
# mtgo_id                                           15870.0
# mtgo_foil_id                                      15871.0
#                                      ...
# life_modifier                                         NaN
# hand_modifier                                         NaN
# attraction_lights                                     NaN
# color_indicator                                       NaN
# content_warning                                       NaN
# Name: 86bf43b1-8d4e-4759-bb2d-0b2e03ba7012, Length: 79, dtype: object
# object                                               card
# oracle_id            0006faf6-7a61-426c-9034-579f2cfcfa83
# multiverse_ids                                   [370780]
# mtgo_id                                           49283.0
# ...

# %%
''' 
    Due to the large number of columns, I made a combined brief listing of the data
    with the field type to prevent having to refer back & forth.
    Ultimately, the field types match the data and no nulls so it's ready to be 
    loaded to a database

    This is handy and I'll store this for future use
'''
'''
data_example = df.head(3).transpose()
frame_info = pd.concat([df.dtypes, df.count()], axis=1)
frame_info.columns = ['Data Type', 'Non-Null Count']
combined = pd.concat([frame_info, data_example], axis=1)
print(combined)
'''
